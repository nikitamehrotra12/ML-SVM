# %%
import os
import os.path
import argparse
import h5py 
from sklearn.manifold import TSNE
from sklearn import svm
import matplotlib.pyplot as plt

# %%
#h5py.run_tests()
filename = "data_1.h5"
file= h5py.File(filename,'r');
#x = file.get('x')
x=file['x'][:]
y=file['y'][:]
#print(x.shape)
#x_embedded = TSNE(n_components=2,random_state=0).fit_transform(x)
#print(x_embedded.shape)

plt.scatter(x[:,0],x[:,1], c= y)
plt.savefig("/Users/nikitamehrotra/plot4.png")
plt.show()
file.close();

filename = "data_3.h5"
file= h5py.File(filename,'r');
x=file['x'][:]
y=file['y'][:]
#x_embedded = TSNE(n_components=2,random_state=0).fit_transform(x)
#print(x_embedded.shape)
#print(file.keys())

plt.scatter(x[:,0],x[:,1], c= y)
plt.savefig("/Users/nikitamehrotra/plot3.png")
plt.show()
file.close();

filename = "data_2.h5"
file= h5py.File(filename,'r');
x=file['x'][:]
y=file['y'][:]
#x_embedded = TSNE(n_components=2,random_state=0).fit_transform(x)
#print(x_embedded.shape)
#print(file.keys())
plt.scatter(x[:,0],x[:,1], c= y)
plt.savefig("/Users/nikitamehrotra/plot2.png")
plt.show()
file.close();

filename = "data_1.h5"
file= h5py.File(filename,'r');
x=file['x'][:]
y=file['y'][:]
#x_embedded = TSNE(n_components=2,random_state=0).fit_transform(x)
#print(x_embedded.shape)
#print(file.keys())
plt.scatter(x[:,0],x[:,1], c= y)
plt.savefig("/Users/nikitamehrotra/plot1.png")
plt.show()
file.close();
